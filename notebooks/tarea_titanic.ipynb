# %%
import pandas as pd
import numpy as np
import matplotlib as plt

path ="/home/josue/apps/iteso-data-analytics/data/raw/titanic/gender_submission.csv"
df=pd.read_csv(path, header=None)
df
# Out:
#         0  1
# 0     892  0
# 1     893  1
# 2     894  0
# 3     895  0
# 4     896  1
# ..    ... ..
# 413  1305  0
# 414  1306  1
# 415  1307  0
# 416  1308  0
# 417  1309  0
#
# [418 rows x 2 columns]

# %%
df.columns=['PassengerID','Survived']
df
# Out:
#      PassengerID  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df
# Out:
#      PassengerID  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
supervivientes=df['Survived'].sum()
df['Survived'].plot(kind='hist')
supervivientes
# Out:
# 152

# %%
path ="/home/josue/apps/iteso-data-analytics/data/raw/titanic/test.csv"
df1=pd.read_csv(path, header=None)
df1.columns=['PassengerId','Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df2=df1
lis=[]
for i in df2.iloc[:,3]:
    if i == 'male':
        i=0
        lis.append(i)
    else:
        i=1
        lis.append(i)

lis=pd.DataFrame(lis)
mujeres=lis.sum()
lis.plot(kind='hist')
mujeres
lis
# Out:
#      0
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# ..  ..
# 413  0
# 414  1
# 415  0
# 416  0
# 417  0
#
# [418 rows x 1 columns]

# %% [markdown]
# Al momento de querer graficar el sexo me di cuenta de una de dos cosas, o solo sobrevivieron la cantidad de mujeres a bordo o simplemente Survived en el otro archivo no era el nombre correcto

# %%
df1['Pclass'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['Age'].plot(kind='hist')
df1['Age'].mean()
# Out:
# 30.272590361445783

# %%
df1['SibSp'].plot(kind='hist')
df1[(df1['SibSp'])==8]
# Out:
#      PassengerId  Pclass                         Name     Sex   Age  SibSp  \
# 188         1080       3              Sage, Miss. Ada  female   NaN      8
# 360         1252       3  Sage, Master. William Henry    male  14.5      8
#
#      Parch    Ticket   Fare Cabin Embarked
# 188      2  CA. 2343  69.55   NaN        S
# 360      2  CA. 2343  69.55   NaN        S

# %%
df1['Parch'].plot(kind='hist')
df1[(df1['Parch'])==9]
# Out:
#      PassengerId  Pclass                            Name     Sex  Age  SibSp  \
# 342         1234       3           Sage, Mr. John George    male  NaN      1
# 365         1257       3  Sage, Mrs. John (Annie Bullen)  female  NaN      1
#
#      Parch    Ticket   Fare Cabin Embarked
# 342      9  CA. 2343  69.55   NaN        S
# 365      9  CA. 2343  69.55   NaN        S

# %%
df1['Fare'].plot(kind='hist')
df1['Fare'].mean()
# Out:
# 35.627188489208635

# %%
lis=[]
for i in df1.iloc[:,9]:
    if i == '':
        i=1
        lis.append(i)
    else:
        i=3
        lis.append(i)

lis=pd.DataFrame(lis)

lis.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
lis=[]
for i in df2.iloc[:,10]:
    if i == 'Q':
        i=0
        lis.append(i)
    elif i== 'S':
        i=1
        lis.append(i)
    else:
        i=2
        lis.append(i)

lis=pd.DataFrame(lis)

lis.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# vamos a ir columna por columna, Passenger ID no se puede sacar mucho ya que es unico para cada uno.
# Pclass que es la clase en la que iba cada pasajero del barco, podemos notar que la clase 1 y 2 estuvieron muy parecidad pero la clase 3 tuvo incluso más del doble de pasajero que en clase 2.
# Name no se puede sacar mucho ya que al igual que ID son unicos.
# Sex y Survivors tienen algo en comun y es que tienen la misma cantidad de mujeres que de sobrevivientes, con más hombres que mujeres.
# Age podemos sacar que la edad que más se repite es entre 20 y los 30 años, teniendo cerca de las 100 personas con estas edades y con un promedio de edad de 30 años entre los pasajeros y la minoria de pasajeros se encuentr entre los 70 años.
# SibSp que habla sobre si los pasajeros tienen hermanos a bordo nos mostró que la mayoria no tiene hermanos a bordo, y lo que más se repite es que los que si tienen solo los de un hermano, aunque hay algunas inconsitencias en los datos, ya que si esto es cierto tendria que haber 9 personas que dijeran que tienen 8 hermanos a bordo, pero solo hay 2 pasajeros que afirmaron que tenian 8 hermanos a bordo.
# Parch que es la cantidad de hijos y padres nos muestra que la mayoria van solos. Ticket como es unico no se puede sacar mucho. Fare que es el precio del boleto, el promedio se encuentra en 35 y la mayoria costó menos de 100.
# Cabin muestra el cuarto de cada pasajero, se podria sacar cuantos contestaron esto y cuantos no lo hicieron pero no encontre la forma.
# Embarked por ultimo nos muestra en que puerto bajaria cada uno de los pasajeros, con esto notamos que la mayoria bajaria en el puerto S, tal es la cantidad que ni en la suma de los demás pasajeros se igualarian las cantidades.

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
